# %% [markdown]
# <a href="https://colab.research.google.com/github/CameronChadwick/data_analysis/blob/main/Moneyball.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# # Files

# %%
pitch_raw = 'https://raw.githubusercontent.com/bobg207/Honors_Data_Analysis/master/2018_MLB_Pitching_Stats_II.txt'
hit_raw = 'https://raw.githubusercontent.com/bobg207/Honors_Data_Analysis/master/2018_MLB_Hitting_Stats.txt'
pitch_data = pd.read_csv(pitch_raw, delim_whitespace=True)
hit_data = pd.read_csv(hit_raw, delim_whitespace=True)
pitch_data
# Out:
#      #                 Team    G      IP     H   ER   HR   BB    SO  WHIP  \
# 0    1    Orioles_Baltimore  162  1431.0  1552  825  234  589  1203  1.50
# 1    2   Royals_Kansas_City  162  1432.0  1542  787  205  549  1157  1.46
# 2    3        Rangers_Texas  162  1431.0  1516  783  222  491  1121  1.40
# 3    4      Reds_Cincinnati  162  1441.0  1491  745  228  532  1258  1.40
# 4    5    Blue_Jays_Toronto  162  1433.2  1476  773  208  551  1298  1.41
# 5    6     Padres_San_Diego  162  1457.0  1430  714  185  519  1399  1.34
# 6    7      Twins_Minnesota  162  1443.1  1425  722  198  573  1377  1.38
# 7    8       Tigers_Detroit  162  1425.1  1423  728  216  491  1215  1.34
# 8    9    White_Sox_Chicago  162  1437.0  1404  774  196  653  1259  1.43
# 9   10     Mariners_Seattle  162  1448.2  1396  664  195  400  1328  1.24
# 10  11        Marlins_Miami  161  1442.0  1388  763  192  605  1249  1.38
# 11  12  Giants_SanFrancisco  162  1461.1  1387  642  156  524  1269  1.31
# 12  13   Pirates_Pittsburgh  161  1434.0  1380  638  174  497  1336  1.31
# 13  14     Rockies_Colorado  163  1452.1  1377  699  184  525  1409  1.31
# 14  15   Phils_Philadelphia  162  1445.2  1366  666  171  500  1465  1.29
# 15  16        Mets_New_York  162  1460.2  1364  661  185  484  1446  1.27
# 16  17  Cardinals_St._Louis  162  1455.1  1354  623  144  593  1337  1.34
# 17  18   Angels_Los_Angeles  162  1437.1  1353  663  205  546  1386  1.32
# 18  19    Indians_Cleveland  162  1457.1  1349  611  200  407  1544  1.20
# 19  20  National_Washington  162  1446.0  1320  649  198  487  1417  1.25
# 20  21         Cubs_Chicago  163  1476.1  1319  598  157  622  1333  1.31
# 21  22       Dbacks_Arizona  162  1463.0  1313  606  174  522  1448  1.25
# 22  23     Yankees_New_York  162  1456.1  1311  611  177  494  1634  1.24
# 23  24       Red_Sox_Boston  162  1458.2  1305  608  176  512  1558  1.25
# 24  25    Athletics_Oakland  162  1465.2  1303  622  184  474  1237  1.21
# 25  26  Dodgers_Los_Angeles  163  1476.0  1279  557  179  422  1565  1.15
# 26  27    Brewers_Milwaukee  163  1461.0  1259  606  173  553  1428  1.24
# 27  28       Rays_Tampa_Bay  162  1448.1  1236  603  164  501  1421  1.20
# 28  28       Braves_Atlanta  162  1456.2  1236  607  153  635  1423  1.28
# 29  30       Astros_Houston  162  1455.0  1164  503  152  435  1687  1.10
#
#     H/9  BB/9  HR/9  SO/9  SO/BB  GB/FB  HR/FB   ERC   ERA   WPCT
# 0   9.8   3.7   1.5   7.6   2.15   1.83  0.222  5.26  5.19  0.290
# 1   9.7   3.5   1.3   7.3   2.22   1.90  0.196  4.89  4.95  0.358
# 2   9.5   3.1   1.4   7.0   2.40   1.86  0.207  4.77  4.93  0.414
# 3   9.3   3.3   1.4   7.9   2.67   2.08  0.232  4.63  4.65  0.414
# 4   9.3   3.5   1.3   8.1   2.44   1.76  0.193  4.67  4.85  0.451
# 5   8.8   3.2   1.1   8.6   2.85   2.05  0.195  4.15  4.41  0.407
# 6   8.9   3.6   1.2   8.6   2.56   1.78  0.193  4.43  4.50  0.481
# 7   9.0   3.1   1.4   7.7   2.58   1.60  0.194  4.35  4.60  0.395
# 8   8.8   4.1   1.2   7.9   2.01   1.66  0.181  4.63  4.85  0.383
# 9   8.7   2.5   1.2   8.3   3.50   1.75  0.184  3.81  4.13  0.549
# 10  8.7   3.8   1.2   7.8   2.35   1.71  0.181  4.31  4.76  0.391
# 11  8.5   3.2   1.0   7.8   2.61   2.12  0.166  3.78  3.95  0.451
# 12  8.7   3.1   1.1   8.4   2.94   1.95  0.178  3.93  4.00  0.509
# 13  8.5   3.3   1.1   8.7   2.81   2.20  0.209  3.96  4.33  0.558
# 14  8.5   3.1   1.1   9.1   3.15   2.18  0.193  3.81  4.15  0.494
# 15  8.4   3.0   1.1   8.9   3.20   1.78  0.181  3.78  4.07  0.475
# 16  8.4   3.7   0.9   8.3   2.46   2.18  0.159  3.82  3.85  0.543
# 17  8.5   3.4   1.3   8.7   2.62   1.86  0.216  4.16  4.15  0.494
# 18  8.3   2.5   1.2   9.5   4.09   1.76  0.200  3.58  3.77  0.562
# 19  8.2   3.0   1.2   8.8   3.15   1.72  0.195  3.78  4.04  0.506
# 20  8.0   3.8   1.0   8.1   2.26   2.13  0.170  3.78  3.65  0.583
# 21  8.1   3.2   1.1   8.9   3.02   2.19  0.192  3.60  3.73  0.506
# 22  8.1   3.1   1.1  10.1   3.37   1.87  0.190  3.57  3.78  0.617
# 23  8.1   3.2   1.1   9.6   3.09   1.80  0.183  3.66  3.75  0.667
# 24  8.0   2.9   1.1   7.6   2.72   1.92  0.183  3.47  3.82  0.599
# 25  7.8   2.6   1.1   9.5   4.09   2.12  0.203  3.17  3.40  0.564
# 26  7.8   3.4   1.1   8.8   2.75   2.10  0.200  3.50  3.73  0.589
# 27  7.7   3.1   1.0   8.8   3.04   1.83  0.168  3.29  3.75  0.556
# 28  7.6   3.9   0.9   8.8   2.40   1.97  0.168  3.52  3.75  0.556
# 29  7.2   2.7   0.9  10.4   3.91   1.96  0.178  2.84  3.11  0.636

# %% [markdown]
# # Moneyball

# %%
def correlation(x, y):
  x_sum = 0
  x_squ = 0
  y_sum = 0
  y_squ = 0
  xy_sum = 0

  for n in range(len(x)):
    xy_sum += x[n] * y[n]
    x_sum += x[n]
    x_squ += x[n] * x[n]
    y_sum += y[n]
    y_squ += y[n] * y[n]

  x_y = x_sum * y_sum
  numerator = len(x) * xy_sum - x_y

  subtract_x = (len(x) * x_squ - x_sum**2)**0.5
  subtract_y = (len(y) * y_squ - y_sum**2)**0.5
  denomonator = subtract_x * subtract_y
  corr_coeff = numerator / denomonator
  return corr_coeff

hit_columns = ['WPCT', 'OBP', 'SLG', 'AVG', 'RBI']
pitch_columns = ['WPCT', 'ERA', 'SO', 'ER', 'HR']
hit_corrs = []
pitch_corrs = []
for index in range(1, len(hit_columns)):
  hit_corr = correlation(hit_data[hit_columns[0]], hit_data[hit_columns[index]])
  hit_corrs.append(hit_corr)
  pitch_corr = correlation(pitch_data[pitch_columns[0]], pitch_data[pitch_columns[index]])
  pitch_corrs.append(pitch_corr)

print(hit_corrs, pitch_corrs)
# Out:
# [0.7983428839608936, 0.7498257778361505, 0.6885904560640973, 0.823533143822496] [-0.8757967641592198, 0.7361970808267791, -0.8748084994941681, -0.6566336239528022]
